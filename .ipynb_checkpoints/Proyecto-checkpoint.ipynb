# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=np.load('/Users/ppassarelli/Desktop/Galileo/Maestria/Ciencia_de_Datos_en_Python/Proyecto/proyecto_data/proyecto_training_data.npy', encoding='ASCII')
len(data)
# Out:
# 1460

# %%
train, validate, test = np.split(data, [int(len(data)*0.8), int(len(data)*0.9)])
train
# Out:
# array([[2.0850e+05, 7.0000e+00, 8.5600e+02, 8.0000e+00, 2.0030e+03,
#         6.5000e+01],
#        [1.8150e+05, 6.0000e+00, 1.2620e+03, 6.0000e+00, 1.9760e+03,
#         8.0000e+01],
#        [2.2350e+05, 7.0000e+00, 9.2000e+02, 6.0000e+00, 2.0010e+03,
#         6.8000e+01],
#        ...,
#        [2.3317e+05, 7.0000e+00, 1.5020e+03, 7.0000e+00, 2.0090e+03,
#         7.9000e+01],
#        [2.4535e+05, 8.0000e+00, 1.6940e+03, 7.0000e+00, 2.0080e+03,
#         6.4000e+01],
#        [1.7300e+05, 6.0000e+00, 9.5900e+02, 7.0000e+00, 2.0000e+03,
#         5.8000e+01]])

# %%
train
# Out:
# array([[2.0850e+05, 7.0000e+00, 8.5600e+02, 8.0000e+00, 2.0030e+03,
#         6.5000e+01],
#        [1.8150e+05, 6.0000e+00, 1.2620e+03, 6.0000e+00, 1.9760e+03,
#         8.0000e+01],
#        [2.2350e+05, 7.0000e+00, 9.2000e+02, 6.0000e+00, 2.0010e+03,
#         6.8000e+01],
#        ...,
#        [2.3317e+05, 7.0000e+00, 1.5020e+03, 7.0000e+00, 2.0090e+03,
#         7.9000e+01],
#        [2.4535e+05, 8.0000e+00, 1.6940e+03, 7.0000e+00, 2.0080e+03,
#         6.4000e+01],
#        [1.7300e+05, 6.0000e+00, 9.5900e+02, 7.0000e+00, 2.0000e+03,
#         5.8000e+01]])

# %%
media=np.mean(train, axis=0)
maximo=np.amax(train, axis=0)
minimo=np.amin(train, axis=0)
rango=np.ptp(train, axis=0)
print(media)
print(maximo)
print(minimo)
print(rango)
#len(train[0])
# Out:
# array([7.201e+05, 9.000e+00, 2.894e+03, 1.200e+01, 1.350e+02,       nan])

# %%
df1=pd.DataFrame(train, columns=['SalePrice', 'OverallQual','1stFlrSF','TotRmsAbvGrd','YearBuilt','LotFrontage'])

# %%
sns.distplot(df1['SalePrice'])
# Out:
# /var/folders/l7/_79ggttn35g9c9gf1rry4wjc0000gq/T/ipykernel_23390/2646407341.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['SalePrice'])
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %%
sns.distplot(df1['OverallQual'])
# Out:
# /var/folders/l7/_79ggttn35g9c9gf1rry4wjc0000gq/T/ipykernel_23390/919177421.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['OverallQual'])
# <Axes: xlabel='OverallQual', ylabel='Density'>

# %%
sns.distplot(df1['1stFlrSF'])
# Out:
# /var/folders/l7/_79ggttn35g9c9gf1rry4wjc0000gq/T/ipykernel_23390/1816406978.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['1stFlrSF'])
# <Axes: xlabel='1stFlrSF', ylabel='Density'>

# %%
sns.distplot(df1['TotRmsAbvGrd'])
# Out:
# /var/folders/l7/_79ggttn35g9c9gf1rry4wjc0000gq/T/ipykernel_23390/1682930943.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['TotRmsAbvGrd'])
# <Axes: xlabel='TotRmsAbvGrd', ylabel='Density'>

# %%
sns.distplot(df1['YearBuilt'])
# Out:
# /var/folders/l7/_79ggttn35g9c9gf1rry4wjc0000gq/T/ipykernel_23390/435493239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['YearBuilt'])
# <Axes: xlabel='YearBuilt', ylabel='Density'>

# %%
sns.distplot(df1['LotFrontage'])
# Out:
# /var/folders/l7/_79ggttn35g9c9gf1rry4wjc0000gq/T/ipykernel_23390/4005630732.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['LotFrontage'])
# <Axes: xlabel='LotFrontage', ylabel='Density'>

# %%
correlacion=np.corrcoef(df1['SalePrice'], df1['OverallQual'])
correlacion
#for col in df1.columns:
#    correlacion=np.corrcoef(df1[col])
    #print(df1[col])
# Out:
# array([[1.        , 0.79399005],
#        [0.79399005, 1.        ]])

# %%
plt.scatter(df1['SalePrice'], df1['OverallQual'])
plt.title(correlacion[0][1])
# Out:
# Text(0.5, 1.0, '0.7939900504626409')

# %%
def entrenar(x, y, epochs, imprimir_error_cada):
    matriz=pd.DataFrame({'x': x, 'y':y})
    print(matriz)
entrenar([1,2,3], [2,5,3], 1, 2)
# Out:
#    x  y
# 0  1  2
# 1  2  5
# 2  3  3
